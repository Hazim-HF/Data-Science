# %% [markdown]
# # Part B

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### a - Load file

# %%
# import library
import numpy as np
import pandas as pd

# %%
# import data
energy = pd.read_csv('./Data/PartB_Q2/Energy.csv')
world_bank = pd.read_table('./Data/PartB_Q2/World_Bank.txt', 
                           skiprows=3)

# look at the first 5 rows from energy data
energy.head()
# Out:
#           Country  Total Energy Supply  Energy Supply per Capita  %Renewable
# 0     Afghanistan         3.210000e+08                      10.0       78.67
# 1         Albania         1.020000e+08                      35.0      100.00
# 2         Algeria         1.959000e+09                      51.0        0.55
# 3  American Samoa                  NaN                       NaN        0.64
# 4         Andorra         9.000000e+06                     121.0       88.70

# %%
# look at the first 5 rows from World Bank data 
world_bank.head()
# Out:
#        Country Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1968  1969  1970  1971  1972  1973  ...          2014  \
# 0  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 2  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 3  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2015          2016          2017          2018          2019  \
# ...

# %% [markdown]
# ### b - merge file

# %%
# Step 1: Read and merge all three files
merged_data = pd.merge(energy, world_bank, left_on = 'Country', 
                       right_on = 'Country', how = 'inner')
merged_data.head()
# Out:
#           Country  Total Energy Supply  Energy Supply per Capita  %Renewable  \
# 0     Afghanistan         3.210000e+08                      10.0       78.67
# 1         Albania         1.020000e+08                      35.0      100.00
# 2         Algeria         1.959000e+09                      51.0        0.55
# 3  American Samoa                  NaN                       NaN        0.64
# 4         Andorra         9.000000e+06                     121.0       88.70
#
#   Country Code                            Indicator Name  Indicator Code  \
# 0          AFG  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 1          ALB  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 2          DZA  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 3          ASM  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 4          AND  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
#
# ...

# %% [markdown]
# ### c - Calculate population and sort descending

# %%
# see all column names
merged_data.columns
# Out:
# Index(['Country', 'Total Energy Supply', 'Energy Supply per Capita',
#        '%Renewable', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023'],
#       dtype='object')

# %%
# Calculate population
merged_data['Population'] = merged_data['Total Energy Supply']/merged_data['Energy Supply per Capita']
merged_data.head()
# Out:
#           Country  Total Energy Supply  Energy Supply per Capita  %Renewable  \
# 0     Afghanistan         3.210000e+08                      10.0       78.67
# 1         Albania         1.020000e+08                      35.0      100.00
# 2         Algeria         1.959000e+09                      51.0        0.55
# 3  American Samoa                  NaN                       NaN        0.64
# 4         Andorra         9.000000e+06                     121.0       88.70
#
#   Country Code                            Indicator Name  Indicator Code  \
# 0          AFG  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 1          ALB  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 2          DZA  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 3          ASM  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 4          AND  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
#
# ...

# %%
md2 = merged_data.sort_values(by='Population', ascending=False)
md2.iloc[4,0]
# Out:
# 'Brazil'

# %%
merged_data.columns
# Out:
# Index(['Country', 'Total Energy Supply', 'Energy Supply per Capita',
#        '%Renewable', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', 'Population'],
#       dtype='object')

# %%
# calculate the mean of energy used for across the years
merged_data.iloc[:,-10:-1].mean(axis=1)
# Out:
# 0      1.675322e+10
# 1      1.199950e+10
# 2      1.673832e+11
# 3               NaN
# 4      3.431637e+09
#            ...
# 180    4.158954e+10
# 181    4.336385e+10
# 182    7.006372e+08
# 183    2.126308e+10
# 184    1.059735e+10
# Length: 185, dtype: float64

# %% [markdown]
# ## Question 3

# %%
import os
os.getcwd()
# Out:
# 'd:\\Data-Science\\Mock Final'

# %%
text1 = pd.read_table('./Data/PartB_Q3a/text1.txt')
text2 = pd.read_table('./Data/PartB_Q3a/text2.txt')
text3 = pd.read_table('./Data/PartB_Q3a/text3.txt')

# %%
files = ['./Data/PartB_Q3a/text1.txt',
         './Data/PartB_Q3a/text2.txt',
         './Data/PartB_Q3a/text3.txt']
text = ''
for file in files:
    with open(file, 'r', encoding='utf-8') as f:
        text += f.read()

text
# Out:
# 'People buy Teslas because of their strong brand image, advanced technology, and extensive Supercharger network. Tesla cars are known for their impressive performance, constant software updates that keep the vehicles current.\nThe Malaysian Meteorological Department has issued a warning of continuous rain in several areas in Sarawak from Tuesday until Wednesday.\nNational shuttler Ng Tze Yong has been ruled out of the prestigious All-England in Birmingham.\n'

# %%
from collections import Counter

char_count = Counter(text)

char_count
# Out:
# Counter({' ': 63,
#          'e': 49,
#          'a': 38,
#          'n': 31,
#          'r': 29,
#          's': 26,
#          't': 25,
#          'o': 23,
#          'i': 22,
#          'l': 16,
#          'u': 14,
#          'h': 13,
#          'c': 11,
#          'g': 11,
#          'd': 11,
#          'p': 8,
#          'f': 7,
#          'm': 7,
#          'y': 5,
#          'T': 5,
#          'v': 5,
#          'w': 5,
#          'b': 4,
#          'k': 4,
#          '.': 4,
#          ',': 3,
#          '\n': 3,
#          'S': 2,
#          'M': 2,
#          'N': 2,
#          'P': 1,
#          'x': 1,
#          'D': 1,
#          'W': 1,
#          'z': 1,
#          'Y': 1,
#          'A': 1,
#          '-': 1,
#          'E': 1,
#          'B': 1})

# %%
type(char_count)
# Out:
# collections.Counter

# %% [markdown]
# ### b -

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### b -

# %%
# read sales and product files
sales = pd.read_csv('./Data/PartB_Q4/sales_data.csv')
product = pd.read_csv('./Data/PartB_Q4/products.csv')

# %%
sales.head()
# Out:
#    Transaction_ID  Product_ID        Date  Quantity      Price  Customer_ID
# 0               1           4  2023-02-04         7  63.180365           10
# 1               2           5  2023-05-03         9  70.980793            3
# 2               3           3  2022-12-18         8  11.492905           18
# 3               4           5  2023-01-20         2  56.088375           13
# 4               5           5  2023-05-10         1  30.384620            7

# %%
product.head()
# Out:
#    Product_ID Product_Name
# 0           1         Milk
# 1           2     Biscuits
# 2           3       Coffee
# 3           4         Meat
# 4           5      Noodles

# %%
sales_product = pd.merge(sales, product, on = 'Product_ID', how = 'inner')
sales_product.head()
# Out:
#    Transaction_ID  Product_ID        Date  Quantity      Price  Customer_ID  \
# 0               1           4  2023-02-04         7  63.180365           10
# 1               2           5  2023-05-03         9  70.980793            3
# 2               3           3  2022-12-18         8  11.492905           18
# 3               4           5  2023-01-20         2  56.088375           13
# 4               5           5  2023-05-10         1  30.384620            7
#
#   Product_Name
# 0         Meat
# 1      Noodles
# 2       Coffee
# 3      Noodles
# 4      Noodles

# %%
# calculate total sales
sales_product['total_sales'] = sales_product['Quantity']*sales_product['Price']

# calculate total sales for each product
total_sales = sales_product.groupby('Product_Name')['total_sales'].sum()
total_sales
# Out:
# Product_Name
# Biscuits    6005.730580
# Coffee      3738.186287
# Meat        7351.175050
# Milk        5888.964655
# Noodles     3927.886522
# Name: total_sales, dtype: float64

# %%
# calculate the average sold quantity for each product
average_quantity = sales_product.groupby('Product_Name')['Quantity'].mean()
average_quantity
# Out:
# Product_Name
# Biscuits    5.047619
# Coffee      5.000000
# Meat        4.923077
# Milk        5.500000
# Noodles     4.052632
# Name: Quantity, dtype: float64

# %%
# plot the total sales for each product
import matplotlib.pyplot as plt
total_sales.plot(kind='bar')
plt.show()

# %% [markdown]
# ### c -

# %%
customer = pd.read_csv('./Data/PartB_Q4/customers.csv')
customer.head()
# Out:
#    Customer_ID            Name                      Email           Country
# 0            1    Justin Mason  johnsonamanda@example.org            Serbia
# 1            2  Michael Turner      hwilliams@example.com            Mexico
# 2            3    John Holland    kinglindsay@example.com             China
# 3            4   Belinda Jones       fordgary@example.org  Marshall Islands
# 4            5     Mary Vargas        vcarter@example.net        Montenegro

# %%
merged2 = pd.merge(sales_product, customer, on = 'Customer_ID', how = 'inner')

# %%
# calculate number of transaction based on country
num_transaction = merged2.groupby('Country')['Transaction_ID'].nunique()
num_transaction
# Out:
# Country
# Australia                       5
# Botswana                        1
# China                           4
# Estonia                         7
# Falkland Islands (Malvinas)     9
# Grenada                         2
# Hong Kong                       7
# Kiribati                        3
# Macao                           4
# Malta                           6
# Marshall Islands                5
# Mexico                          5
# Montenegro                     14
# Namibia                         1
# Nauru                           4
# Poland                          6
# Samoa                           5
# Serbia                          8
# Sudan                           4
# Name: Transaction_ID, dtype: int64

# %%
# calculate total sales based on country
total_sales_country = merged2.groupby('Country')['total_sales'].sum()
total_sales_country
# Out:
# Country
# Australia                      1037.682251
# Botswana                         66.979131
# China                          1274.496189
# Estonia                        2352.322046
# Falkland Islands (Malvinas)    1996.388311
# Grenada                         419.527760
# Hong Kong                      2153.117167
# Kiribati                        818.796555
# Macao                          1040.062429
# Malta                          1764.860745
# Marshall Islands               1145.120569
# Mexico                          948.728261
# Montenegro                     3504.488646
# Namibia                         231.552679
# Nauru                          1478.535553
# Poland                         1512.975217
# Samoa                          1468.747935
# Serbia                         3025.326958
# Sudan                           672.234691
# Name: total_sales, dtype: float64

# %%
type(total_sales_country)
# Out:
# pandas.core.series.Series

# %%
df = total_sales_country.to_frame().sort_values(by = 'total_sales', ascending=False)
df
# Out:
#                              total_sales
# Country
# Montenegro                   3504.488646
# Serbia                       3025.326958
# Estonia                      2352.322046
# Hong Kong                    2153.117167
# Falkland Islands (Malvinas)  1996.388311
# Malta                        1764.860745
# Poland                       1512.975217
# Nauru                        1478.535553
# Samoa                        1468.747935
# China                        1274.496189
# Marshall Islands             1145.120569
# Macao                        1040.062429
# Australia                    1037.682251
# Mexico                        948.728261
# Kiribati                      818.796555
# Sudan                         672.234691
# Grenada                       419.527760
# Namibia                       231.552679
# Botswana                       66.979131

# %%
df['Country'] = df.index
df
# Out:
#                              total_sales                      Country
# Country
# Montenegro                   3504.488646                   Montenegro
# Serbia                       3025.326958                       Serbia
# Estonia                      2352.322046                      Estonia
# Hong Kong                    2153.117167                    Hong Kong
# Falkland Islands (Malvinas)  1996.388311  Falkland Islands (Malvinas)
# Malta                        1764.860745                        Malta
# Poland                       1512.975217                       Poland
# Nauru                        1478.535553                        Nauru
# Samoa                        1468.747935                        Samoa
# China                        1274.496189                        China
# Marshall Islands             1145.120569             Marshall Islands
# Macao                        1040.062429                        Macao
# ...

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
#     total_sales                      Country
# 0   3504.488646                   Montenegro
# 1   3025.326958                       Serbia
# 2   2352.322046                      Estonia
# 3   2153.117167                    Hong Kong
# 4   1996.388311  Falkland Islands (Malvinas)
# 5   1764.860745                        Malta
# 6   1512.975217                       Poland
# 7   1478.535553                        Nauru
# 8   1468.747935                        Samoa
# 9   1274.496189                        China
# 10  1145.120569             Marshall Islands
# 11  1040.062429                        Macao
# 12  1037.682251                    Australia
# 13   948.728261                       Mexico
# 14   818.796555                     Kiribati
# 15   672.234691                        Sudan
# 16   419.527760                      Grenada
# 17   231.552679                      Namibia
# 18    66.979131                     Botswana

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### a -

# %%
clinical = pd.read_csv('./Data/PartB_Q5/clinical_study_data.csv')
clinical.head()
# Out:
#    age  glucose_level  HbA1c  diabetes_duration treatment_type complications
# 0   63          133.8    6.0                  3     medication           yes
# 1   76          122.6    7.6                  8      lifestyle            no
# 2   53           74.7    6.9                 16      lifestyle           yes
# 3   39          141.6    4.0                 13        insulin           yes
# 4   67           94.7    7.0                 18     medication           yes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x='age', y='glucose_level', data=clinical)

plt.title('Age vs Glucose Level')

plt.show()

# %%
sns.scatterplot(x='age', y='glucose_level', data=clinical, hue='treatment_type')
plt.title('Age vs Glucose Level')
plt.show()

# %%
# Interpolate
import pandas as pd
import numpy as np

# Create a sample DataFrame with missing values
data = {'A': [1, np.nan, 3, np.nan, 5], 'B': [2, 4, np.nan, 8, 10]}
df = pd.DataFrame(data)

# Apply interpolation
df_interpolated = df.interpolate()

print(df_interpolated)
# Out:
#      A     B
# 0  1.0   2.0
# 1  2.0   4.0
# 2  3.0   6.0
# 3  4.0   8.0
# 4  5.0  10.0

# %%
#These methods are useful for smooth interpolations, especially for time series data.
df.interpolate(method='polynomial', order=2)  # Quadratic interpolation
df.interpolate(method='spline', order=3)      # Cubic spline interpolation
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[123], line 3
#       1 #These methods are useful for smooth interpolations, especially for time series data.
#       2 df.interpolate(method='polynomial', order=2)  # Quadratic interpolation
# ----> 3 df.interpolate(method='spline', order=3)      # Cubic spline interpolation
#
# File c:\Users\hazim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:8499, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8497 else:
#    8498     index = missing.get_interp_index(method, obj.index)
# -> 8499     new_data = obj._mgr.interpolate(
#    8500         method=method,
#    8501         index=index,
#    8502         limit=limit,
#    8503         limit_direction=limit_direction,
#    8504         limit_area=limit_area,
# ...

# %%
data = {'A': [1, np.nan, 3, np.nan, 5], 'B': [2, 4, np.nan, 8, 10]}
df = pd.DataFrame(data)
df.interpolate(limit=1, limit_direction='forward')
# Out:
#      A     B
# 0  1.0   2.0
# 1  2.0   4.0
# 2  3.0   6.0
# 3  4.0   8.0
# 4  5.0  10.0
